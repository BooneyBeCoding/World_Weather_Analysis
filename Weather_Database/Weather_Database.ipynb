# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=03357120a9caa81064d2a01508c51960

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
#city_url = url + "&q=" + "Boston"
#city_weather = requests.get(city_url)
#city_weather.json()

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | phuthaditjhaba
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | ponta do sol
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | namibe
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | karoi
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | college
# Processing Record 12 of Set 1 | lompoc
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | pisco
# Processing Record 16 of Set 1 | vung tau
# Processing Record 17 of Set 1 | belaya gora
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | mount gambier
# Processing Record 22 of Set 1 | boguchany
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | kahului
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | vao
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | najran
# Processing Record 32 of Set 1 | ashta
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | laguna
# Processing Record 37 of Set 1 | grand gaube
# Processing Record 38 of Set 1 | saint george
# Processing Record 39 of Set 1 | saint-pierre
# Processing Record 40 of Set 1 | tiksi
# Processing Record 41 of Set 1 | te anau
# Processing Record 42 of Set 1 | margherita
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | bourail
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | nefteyugansk
# Processing Record 49 of Set 1 | domoni
# Processing Record 50 of Set 1 | karratha
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | morondava
# Processing Record 3 of Set 2 | kyra
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | sorong
# Processing Record 6 of Set 2 | cockburn town
# Processing Record 7 of Set 2 | altay
# Processing Record 8 of Set 2 | hay river
# Processing Record 9 of Set 2 | whitecourt
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | samoded
# Processing Record 12 of Set 2 | washington
# Processing Record 13 of Set 2 | swan river
# Processing Record 14 of Set 2 | mezen
# Processing Record 15 of Set 2 | severodvinsk
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | sitka
# Processing Record 18 of Set 2 | luderitz
# Processing Record 19 of Set 2 | hirakud
# Processing Record 20 of Set 2 | saldanha
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | lasa
# Processing Record 23 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | urumqi
# Processing Record 26 of Set 2 | santiago del estero
# Processing Record 27 of Set 2 | minab
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | nanakuli
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | iberia
# Processing Record 32 of Set 2 | penzance
# Processing Record 33 of Set 2 | shumskiy
# Processing Record 34 of Set 2 | santa isabel do rio negro
# Processing Record 35 of Set 2 | cedar city
# Processing Record 36 of Set 2 | havoysund
# Processing Record 37 of Set 2 | pachino
# Processing Record 38 of Set 2 | mana
# Processing Record 39 of Set 2 | rafiganj
# Processing Record 40 of Set 2 | bishop auckland
# Processing Record 41 of Set 2 | pierre
# Processing Record 42 of Set 2 | arraial do cabo
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | okha
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | esperance
# Processing Record 47 of Set 2 | dunedin
# Processing Record 48 of Set 2 | ust-kuyga
# Processing Record 49 of Set 2 | luebo
# Processing Record 50 of Set 2 | sociedad
# Processing Record 1 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 3 | pangnirtung
# Processing Record 3 of Set 3 | enid
# Processing Record 4 of Set 3 | luxor
# Processing Record 5 of Set 3 | hirara
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | sona
# Processing Record 8 of Set 3 | kaitangata
# Processing Record 9 of Set 3 | port alfred
# Processing Record 10 of Set 3 | lac du bonnet
# Processing Record 11 of Set 3 | guerrero negro
# Processing Record 12 of Set 3 | east london
# Processing Record 13 of Set 3 | damghan
# Processing Record 14 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 3 | westport
# Processing Record 16 of Set 3 | iqaluit
# Processing Record 17 of Set 3 | nome
# Processing Record 18 of Set 3 | ronda
# Processing Record 19 of Set 3 | astana
# Processing Record 20 of Set 3 | fort nelson
# Processing Record 21 of Set 3 | richards bay
# Processing Record 22 of Set 3 | kavaratti
# Processing Record 23 of Set 3 | porkhov
# Processing Record 24 of Set 3 | jilib
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | calvinia
# Processing Record 27 of Set 3 | lorengau
# Processing Record 28 of Set 3 | tasiilaq
# Processing Record 29 of Set 3 | akbarpur
# Processing Record 30 of Set 3 | manaure
# Processing Record 31 of Set 3 | barra do garcas
# Processing Record 32 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 3 | santa rosa
# Processing Record 34 of Set 3 | mareeba
# Processing Record 35 of Set 3 | surgut
# Processing Record 36 of Set 3 | bandar-e lengeh
# Processing Record 37 of Set 3 | nikolskoye
# Processing Record 38 of Set 3 | chivacoa
# Processing Record 39 of Set 3 | lebu
# Processing Record 40 of Set 3 | vama buzaului
# City not found. Skipping...
# Processing Record 41 of Set 3 | khatanga
# Processing Record 42 of Set 3 | bluff
# Processing Record 43 of Set 3 | thinadhoo
# Processing Record 44 of Set 3 | berlevag
# Processing Record 45 of Set 3 | tazovskiy
# Processing Record 46 of Set 3 | mertoyudan
# Processing Record 47 of Set 3 | mahebourg
# Processing Record 48 of Set 3 | buhe
# Processing Record 49 of Set 3 | urdoma
# Processing Record 50 of Set 3 | labuhan
# Processing Record 1 of Set 4 | garissa
# Processing Record 2 of Set 4 | bayanday
# Processing Record 3 of Set 4 | ancud
# Processing Record 4 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 4 | mount isa
# Processing Record 6 of Set 4 | wagar
# Processing Record 7 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 4 | arandis
# Processing Record 9 of Set 4 | comodoro rivadavia
# Processing Record 10 of Set 4 | namatanai
# Processing Record 11 of Set 4 | sedelnikovo
# City not found. Skipping...
# Processing Record 12 of Set 4 | nantucket
# Processing Record 13 of Set 4 | shulan
# Processing Record 14 of Set 4 | mirnyy
# Processing Record 15 of Set 4 | nakambala
# Processing Record 16 of Set 4 | palmer
# Processing Record 17 of Set 4 | amahai
# Processing Record 18 of Set 4 | moron
# Processing Record 19 of Set 4 | hamilton
# Processing Record 20 of Set 4 | bengkulu
# Processing Record 21 of Set 4 | hajnowka
# Processing Record 22 of Set 4 | muriti
# Processing Record 23 of Set 4 | muros
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | bathsheba
# Processing Record 27 of Set 4 | tura
# Processing Record 28 of Set 4 | tilichiki
# Processing Record 29 of Set 4 | konya
# Processing Record 30 of Set 4 | okhotsk
# Processing Record 31 of Set 4 | huarmey
# Processing Record 32 of Set 4 | quarteira
# Processing Record 33 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 34 of Set 4 | aykhal
# Processing Record 35 of Set 4 | alepe
# Processing Record 36 of Set 4 | memmingen
# Processing Record 37 of Set 4 | vinh
# Processing Record 38 of Set 4 | matara
# Processing Record 39 of Set 4 | shahr-e babak
# Processing Record 40 of Set 4 | ambagarh chauki
# Processing Record 41 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 4 | ponta delgada
# Processing Record 43 of Set 4 | katsuura
# Processing Record 44 of Set 4 | eldikan
# City not found. Skipping...
# Processing Record 45 of Set 4 | ambon
# Processing Record 46 of Set 4 | sturgis
# Processing Record 47 of Set 4 | visby
# Processing Record 48 of Set 4 | inuvik
# Processing Record 49 of Set 4 | geraldton
# Processing Record 50 of Set 4 | rio grande
# Processing Record 1 of Set 5 | sola
# Processing Record 2 of Set 5 | port angeles
# Processing Record 3 of Set 5 | nemuro
# Processing Record 4 of Set 5 | sao jose da coroa grande
# Processing Record 5 of Set 5 | longyearbyen
# Processing Record 6 of Set 5 | pevek
# Processing Record 7 of Set 5 | castelo do piaui
# Processing Record 8 of Set 5 | nyurba
# Processing Record 9 of Set 5 | jaumave
# Processing Record 10 of Set 5 | kodiak
# Processing Record 11 of Set 5 | saint-joseph
# Processing Record 12 of Set 5 | constitucion
# Processing Record 13 of Set 5 | ostrovnoy
# Processing Record 14 of Set 5 | thompson
# Processing Record 15 of Set 5 | kulhudhuffushi
# Processing Record 16 of Set 5 | mecca
# Processing Record 17 of Set 5 | yulara
# Processing Record 18 of Set 5 | half moon bay
# Processing Record 19 of Set 5 | kamarion
# Processing Record 20 of Set 5 | yarada
# Processing Record 21 of Set 5 | guhagar
# Processing Record 22 of Set 5 | san patricio
# Processing Record 23 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 5 | shingu
# Processing Record 25 of Set 5 | iralaya
# Processing Record 26 of Set 5 | port hardy
# Processing Record 27 of Set 5 | lapy
# Processing Record 28 of Set 5 | sao joao da barra
# Processing Record 29 of Set 5 | columbus
# Processing Record 30 of Set 5 | necochea
# Processing Record 31 of Set 5 | zyryanka
# Processing Record 32 of Set 5 | zarinsk
# Processing Record 33 of Set 5 | deputatskiy
# Processing Record 34 of Set 5 | yeniseysk
# Processing Record 35 of Set 5 | coari
# Processing Record 36 of Set 5 | puerto quijarro
# Processing Record 37 of Set 5 | puqi
# Processing Record 38 of Set 5 | leningradskiy
# Processing Record 39 of Set 5 | kavieng
# Processing Record 40 of Set 5 | talnakh
# Processing Record 41 of Set 5 | flic en flac
# Processing Record 42 of Set 5 | upernavik
# Processing Record 43 of Set 5 | lata
# Processing Record 44 of Set 5 | tokmak
# Processing Record 45 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 47 of Set 5 | vostok
# Processing Record 48 of Set 5 | toora-khem
# Processing Record 49 of Set 5 | viedma
# Processing Record 50 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 6 | ongandjera
# Processing Record 2 of Set 6 | inirida
# Processing Record 3 of Set 6 | mitu
# Processing Record 4 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 6 | sayat
# Processing Record 6 of Set 6 | changping
# Processing Record 7 of Set 6 | isangel
# Processing Record 8 of Set 6 | sao filipe
# Processing Record 9 of Set 6 | padang
# Processing Record 10 of Set 6 | sarangani
# Processing Record 11 of Set 6 | buala
# Processing Record 12 of Set 6 | mayo
# Processing Record 13 of Set 6 | lagoa
# Processing Record 14 of Set 6 | carnarvon
# Processing Record 15 of Set 6 | umba
# Processing Record 16 of Set 6 | carndonagh
# Processing Record 17 of Set 6 | klaksvik
# Processing Record 18 of Set 6 | gobabis
# Processing Record 19 of Set 6 | raga
# Processing Record 20 of Set 6 | manalurpet
# City not found. Skipping...
# Processing Record 21 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 22 of Set 6 | benguela
# Processing Record 23 of Set 6 | balkanabat
# Processing Record 24 of Set 6 | coquimbo
# Processing Record 25 of Set 6 | san pedro
# Processing Record 26 of Set 6 | prainha
# Processing Record 27 of Set 6 | marawi
# Processing Record 28 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 29 of Set 6 | alekseyevsk
# Processing Record 30 of Set 6 | ialibu
# Processing Record 31 of Set 6 | bethel
# Processing Record 32 of Set 6 | ramon
# Processing Record 33 of Set 6 | port augusta
# Processing Record 34 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 6 | imbituba
# Processing Record 36 of Set 6 | atlantis
# Processing Record 37 of Set 6 | haines junction
# Processing Record 38 of Set 6 | shache
# Processing Record 39 of Set 6 | somerset west
# Processing Record 40 of Set 6 | ornskoldsvik
# Processing Record 41 of Set 6 | andenes
# Processing Record 42 of Set 6 | victoria
# Processing Record 43 of Set 6 | the valley
# Processing Record 44 of Set 6 | salalah
# Processing Record 45 of Set 6 | adolfo lopez mateos
# Processing Record 46 of Set 6 | narsaq
# Processing Record 47 of Set 6 | codrington
# Processing Record 48 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 6 | bonthe
# Processing Record 50 of Set 6 | chateaubelair
# Processing Record 1 of Set 7 | emba
# Processing Record 2 of Set 7 | bam
# Processing Record 3 of Set 7 | sakakah
# Processing Record 4 of Set 7 | mogadishu
# Processing Record 5 of Set 7 | aksu
# Processing Record 6 of Set 7 | tomatlan
# Processing Record 7 of Set 7 | northampton
# Processing Record 8 of Set 7 | zhigansk
# Processing Record 9 of Set 7 | srednekolymsk
# Processing Record 10 of Set 7 | kusadak
# Processing Record 11 of Set 7 | honiara
# Processing Record 12 of Set 7 | inhambane
# Processing Record 13 of Set 7 | risor
# Processing Record 14 of Set 7 | masuda
# Processing Record 15 of Set 7 | georgetown
# Processing Record 16 of Set 7 | rongcheng
# Processing Record 17 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 7 | providencia
# Processing Record 19 of Set 7 | asau
# Processing Record 20 of Set 7 | jalu
# Processing Record 21 of Set 7 | boende
# Processing Record 22 of Set 7 | johnshaven
# Processing Record 23 of Set 7 | chuy
# Processing Record 24 of Set 7 | hualmay
# Processing Record 25 of Set 7 | monte escobedo
# Processing Record 26 of Set 7 | kungsbacka
# Processing Record 27 of Set 7 | bratsk
# Processing Record 28 of Set 7 | san quintin
# Processing Record 29 of Set 7 | aloleng
# Processing Record 30 of Set 7 | novikovo
# Processing Record 31 of Set 7 | gushikawa
# Processing Record 32 of Set 7 | batagay-alyta
# Processing Record 33 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 34 of Set 7 | faanui
# Processing Record 35 of Set 7 | wilmington
# Processing Record 36 of Set 7 | vestmanna
# Processing Record 37 of Set 7 | mehamn
# Processing Record 38 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 7 | puerto del rosario
# Processing Record 40 of Set 7 | gambela
# Processing Record 41 of Set 7 | ust-karsk
# Processing Record 42 of Set 7 | kisangani
# Processing Record 43 of Set 7 | rio cuarto
# Processing Record 44 of Set 7 | esil
# Processing Record 45 of Set 7 | mosquera
# Processing Record 46 of Set 7 | bambous virieux
# Processing Record 47 of Set 7 | taoudenni
# Processing Record 48 of Set 7 | saint-andre
# Processing Record 49 of Set 7 | a
# City not found. Skipping...
# Processing Record 50 of Set 7 | usinsk
# Processing Record 1 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 2 of Set 8 | great falls
# Processing Record 3 of Set 8 | roald
# Processing Record 4 of Set 8 | akdagmadeni
# Processing Record 5 of Set 8 | tsabong
# Processing Record 6 of Set 8 | ulaangom
# Processing Record 7 of Set 8 | say
# Processing Record 8 of Set 8 | bereda
# Processing Record 9 of Set 8 | sorland
# Processing Record 10 of Set 8 | sabang
# Processing Record 11 of Set 8 | tangwani
# Processing Record 12 of Set 8 | kruisfontein
# Processing Record 13 of Set 8 | clyde river
# Processing Record 14 of Set 8 | saint-philippe
# Processing Record 15 of Set 8 | iquitos
# Processing Record 16 of Set 8 | bakchar
# Processing Record 17 of Set 8 | quatre cocos
# Processing Record 18 of Set 8 | chute-aux-outardes
# Processing Record 19 of Set 8 | taruma
# Processing Record 20 of Set 8 | buraydah
# Processing Record 21 of Set 8 | merauke
# Processing Record 22 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 8 | steamboat springs
# Processing Record 24 of Set 8 | vestmannaeyjar
# Processing Record 25 of Set 8 | coxim
# Processing Record 26 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 8 | phan thiet
# Processing Record 29 of Set 8 | port blair
# Processing Record 30 of Set 8 | charters towers
# Processing Record 31 of Set 8 | marsabit
# Processing Record 32 of Set 8 | kamaishi
# Processing Record 33 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 8 | santiago
# Processing Record 35 of Set 8 | mayumba
# Processing Record 36 of Set 8 | homer
# Processing Record 37 of Set 8 | buba
# Processing Record 38 of Set 8 | dedza
# Processing Record 39 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 8 | tanjong karang
# City not found. Skipping...
# Processing Record 41 of Set 8 | fairbanks
# Processing Record 42 of Set 8 | akyab
# Processing Record 43 of Set 8 | neiafu
# Processing Record 44 of Set 8 | norman wells
# Processing Record 45 of Set 8 | tessalit
# Processing Record 46 of Set 8 | mandla
# Processing Record 47 of Set 8 | husavik
# Processing Record 48 of Set 8 | paciran
# Processing Record 49 of Set 8 | nuuk
# Processing Record 50 of Set 8 | uyuni
# Processing Record 1 of Set 9 | pestyaki
# Processing Record 2 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 9 | krems
# Processing Record 4 of Set 9 | houma
# Processing Record 5 of Set 9 | beisfjord
# Processing Record 6 of Set 9 | rundu
# Processing Record 7 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 8 of Set 9 | baiyin
# Processing Record 9 of Set 9 | coihaique
# Processing Record 10 of Set 9 | bundaberg
# Processing Record 11 of Set 9 | talakan
# Processing Record 12 of Set 9 | byron bay
# Processing Record 13 of Set 9 | san cristobal
# Processing Record 14 of Set 9 | hasaki
# Processing Record 15 of Set 9 | ugoofaaru
# Processing Record 16 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 17 of Set 9 | farsund
# Processing Record 18 of Set 9 | severo-kurilsk
# Processing Record 19 of Set 9 | manadhoo
# Processing Record 20 of Set 9 | simao
# Processing Record 21 of Set 9 | isla vista
# Processing Record 22 of Set 9 | zaysan
# Processing Record 23 of Set 9 | coos bay
# Processing Record 24 of Set 9 | sinop
# Processing Record 25 of Set 9 | aviles
# Processing Record 26 of Set 9 | picos
# Processing Record 27 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 28 of Set 9 | mission viejo
# Processing Record 29 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 9 | lakes entrance
# Processing Record 31 of Set 9 | cabo san lucas
# Processing Record 32 of Set 9 | longmont
# Processing Record 33 of Set 9 | ussel
# Processing Record 34 of Set 9 | souillac
# Processing Record 35 of Set 9 | la ronge
# Processing Record 36 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 9 | lavrentiya
# Processing Record 38 of Set 9 | road town
# Processing Record 39 of Set 9 | takoradi
# Processing Record 40 of Set 9 | havelock
# Processing Record 41 of Set 9 | san carlos del zulia
# Processing Record 42 of Set 9 | rorvik
# Processing Record 43 of Set 9 | beringovskiy
# Processing Record 44 of Set 9 | stralsund
# Processing Record 45 of Set 9 | casambalangan
# Processing Record 46 of Set 9 | komsomolskiy
# Processing Record 47 of Set 9 | armacao dos buzios
# City not found. Skipping...
# Processing Record 48 of Set 9 | vila velha
# Processing Record 49 of Set 9 | bani walid
# Processing Record 50 of Set 9 | pavelets
# Processing Record 1 of Set 10 | oranjemund
# Processing Record 2 of Set 10 | sao mateus
# Processing Record 3 of Set 10 | ixtapa
# Processing Record 4 of Set 10 | parati
# Processing Record 5 of Set 10 | povenets
# Processing Record 6 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 7 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 8 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 10 | naze
# Processing Record 10 of Set 10 | torrington
# Processing Record 11 of Set 10 | visegrad
# Processing Record 12 of Set 10 | evensk
# Processing Record 13 of Set 10 | puerto leguizamo
# Processing Record 14 of Set 10 | bousse
# Processing Record 15 of Set 10 | sungairaya
# Processing Record 16 of Set 10 | sumbe
# Processing Record 17 of Set 10 | tarn taran
# Processing Record 18 of Set 10 | noshiro
# Processing Record 19 of Set 10 | dukat
# Processing Record 20 of Set 10 | noumea
# Processing Record 21 of Set 10 | whitehorse
# Processing Record 22 of Set 10 | yelkhovka
# Processing Record 23 of Set 10 | juegang
# Processing Record 24 of Set 10 | quang ngai
# Processing Record 25 of Set 10 | camacha
# Processing Record 26 of Set 10 | manta
# Processing Record 27 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 10 | kargasok
# Processing Record 29 of Set 10 | ati
# Processing Record 30 of Set 10 | lajeado
# Processing Record 31 of Set 10 | baykit
# Processing Record 32 of Set 10 | gorontalo
# Processing Record 33 of Set 10 | bardiyah
# Processing Record 34 of Set 10 | shakiso
# Processing Record 35 of Set 10 | mokhsogollokh
# Processing Record 36 of Set 10 | dzhebariki-khaya
# Processing Record 37 of Set 10 | budingen
# Processing Record 38 of Set 10 | teya
# Processing Record 39 of Set 10 | harper
# Processing Record 40 of Set 10 | la asuncion
# Processing Record 41 of Set 10 | vredendal
# Processing Record 42 of Set 10 | lima
# Processing Record 43 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 44 of Set 10 | boa vista
# Processing Record 45 of Set 10 | port-cartier
# Processing Record 46 of Set 10 | great yarmouth
# Processing Record 47 of Set 10 | verkhnyaya inta
# Processing Record 48 of Set 10 | krasnoselkup
# Processing Record 49 of Set 10 | shimanovsk
# Processing Record 50 of Set 10 | poso
# Processing Record 1 of Set 11 | alofi
# Processing Record 2 of Set 11 | korampallam
# Processing Record 3 of Set 11 | poum
# Processing Record 4 of Set 11 | villa alemana
# Processing Record 5 of Set 11 | lalin
# Processing Record 6 of Set 11 | piacabucu
# Processing Record 7 of Set 11 | itoman
# Processing Record 8 of Set 11 | barras
# Processing Record 9 of Set 11 | storforshei
# Processing Record 10 of Set 11 | banjar
# Processing Record 11 of Set 11 | cap malheureux
# Processing Record 12 of Set 11 | nouadhibou
# Processing Record 13 of Set 11 | yumen
# Processing Record 14 of Set 11 | nebbi
# Processing Record 15 of Set 11 | ipixuna
# Processing Record 16 of Set 11 | mahajanga
# Processing Record 17 of Set 11 | paris
# Processing Record 18 of Set 11 | cap-aux-meules
# Processing Record 19 of Set 11 | nishihara
# Processing Record 20 of Set 11 | caconda
# Processing Record 21 of Set 11 | eyl
# Processing Record 22 of Set 11 | hovd
# Processing Record 23 of Set 11 | antequera
# Processing Record 24 of Set 11 | tateyama
# Processing Record 25 of Set 11 | tungor
# Processing Record 26 of Set 11 | shubarkuduk
# Processing Record 27 of Set 11 | a coruna
# Processing Record 28 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 29 of Set 11 | shubarshi
# Processing Record 30 of Set 11 | tuatapere
# Processing Record 31 of Set 11 | beira
# Processing Record 32 of Set 11 | colares
# Processing Record 33 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 11 | ambilobe
# Processing Record 35 of Set 11 | awbari
# Processing Record 36 of Set 11 | igarka
# Processing Record 37 of Set 11 | ocumare del tuy
# Processing Record 38 of Set 11 | saint anthony
# Processing Record 39 of Set 11 | wuwei
# Processing Record 40 of Set 11 | acapulco
# Processing Record 41 of Set 11 | kukuna
# Processing Record 42 of Set 11 | makakilo city
# Processing Record 43 of Set 11 | fairfield
# Processing Record 44 of Set 11 | channel-port aux basques
# Processing Record 45 of Set 11 | lermontovka
# Processing Record 46 of Set 11 | jomalig
# City not found. Skipping...
# Processing Record 47 of Set 11 | vardo
# Processing Record 48 of Set 11 | markdorf
# Processing Record 49 of Set 11 | vikhorevka
# Processing Record 50 of Set 11 | adrar
# Processing Record 1 of Set 12 | aktash
# Processing Record 2 of Set 12 | saint-leu
# Processing Record 3 of Set 12 | paamiut
# Processing Record 4 of Set 12 | mandalgovi
# Processing Record 5 of Set 12 | zhoukou
# Processing Record 6 of Set 12 | cannington
# Processing Record 7 of Set 12 | gat
# Processing Record 8 of Set 12 | fortuna
# Processing Record 9 of Set 12 | burica
# City not found. Skipping...
# Processing Record 10 of Set 12 | chake chake
# Processing Record 11 of Set 12 | provideniya
# Processing Record 12 of Set 12 | kurilsk
# Processing Record 13 of Set 12 | nanortalik
# Processing Record 14 of Set 12 | victor harbor
# Processing Record 15 of Set 12 | vila franca do campo
# Processing Record 16 of Set 12 | carnduff
# Processing Record 17 of Set 12 | sobolevo
# Processing Record 18 of Set 12 | tshela
# Processing Record 19 of Set 12 | rute
# Processing Record 20 of Set 12 | salinopolis
# Processing Record 21 of Set 12 | ravar
# Processing Record 22 of Set 12 | port lincoln
# Processing Record 23 of Set 12 | mercedes
# Processing Record 24 of Set 12 | teahupoo
# Processing Record 25 of Set 12 | antofagasta
# Processing Record 26 of Set 12 | lukovetskiy
# Processing Record 27 of Set 12 | asmara
# Processing Record 28 of Set 12 | dire
# Processing Record 29 of Set 12 | entebbe
# Processing Record 30 of Set 12 | beloha
# Processing Record 31 of Set 12 | chibuto
# Processing Record 32 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 33 of Set 12 | axim
# Processing Record 34 of Set 12 | iskateley
# Processing Record 35 of Set 12 | pontes e lacerda
# Processing Record 36 of Set 12 | port hedland
# Processing Record 37 of Set 12 | rosarito
# Processing Record 38 of Set 12 | caraquet
# Processing Record 39 of Set 12 | mizdah
# Processing Record 40 of Set 12 | katangli
# Processing Record 41 of Set 12 | wakkanai
# Processing Record 42 of Set 12 | scandiano
# Processing Record 43 of Set 12 | leesburg
# Processing Record 44 of Set 12 | chatham
# Processing Record 45 of Set 12 | hastings
# Processing Record 46 of Set 12 | lushunkou
# City not found. Skipping...
# Processing Record 47 of Set 12 | alekseyevka
# Processing Record 48 of Set 12 | mocuba
# Processing Record 49 of Set 12 | yuxia
# Processing Record 50 of Set 12 | zhoucheng
# Processing Record 1 of Set 13 | porto murtinho
# Processing Record 2 of Set 13 | nichinan
# Processing Record 3 of Set 13 | odweyne
# Processing Record 4 of Set 13 | kirakira
# Processing Record 5 of Set 13 | yashan
# Processing Record 6 of Set 13 | abalak
# Processing Record 7 of Set 13 | beyneu
# Processing Record 8 of Set 13 | zeya
# Processing Record 9 of Set 13 | barcelos
# Processing Record 10 of Set 13 | pryozerne
# Processing Record 11 of Set 13 | marzuq
# Processing Record 12 of Set 13 | basoko
# Processing Record 13 of Set 13 | boyolangu
# Processing Record 14 of Set 13 | chhabra
# Processing Record 15 of Set 13 | general roca
# Processing Record 16 of Set 13 | chumikan
# Processing Record 17 of Set 13 | torbay
# Processing Record 18 of Set 13 | portland
# Processing Record 19 of Set 13 | thano bula khan
# City not found. Skipping...
# Processing Record 20 of Set 13 | pacific grove
# Processing Record 21 of Set 13 | cayenne
# Processing Record 22 of Set 13 | bara
# Processing Record 23 of Set 13 | pedro betancourt
# Processing Record 24 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 13 | merrill
# Processing Record 26 of Set 13 | araouane
# Processing Record 27 of Set 13 | port macquarie
# Processing Record 28 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 13 | itagiba
# Processing Record 30 of Set 13 | aklavik
# Processing Record 31 of Set 13 | riobamba
# Processing Record 32 of Set 13 | vysokogornyy
# Processing Record 33 of Set 13 | katherine
# Processing Record 34 of Set 13 | alihe
# Processing Record 35 of Set 13 | vermilion
# Processing Record 36 of Set 13 | caraballeda
# Processing Record 37 of Set 13 | chateauroux
# Processing Record 38 of Set 13 | labytnangi
# Processing Record 39 of Set 13 | sakaiminato
# Processing Record 40 of Set 13 | kiama
# Processing Record 41 of Set 13 | cibeureum
# Processing Record 42 of Set 13 | doka
# Processing Record 43 of Set 13 | kutum
# Processing Record 44 of Set 13 | ust-ishim
# Processing Record 45 of Set 13 | canutama
# Processing Record 46 of Set 13 | broken hill
# Processing Record 47 of Set 13 | emilio carranza
# Processing Record 48 of Set 13 | saint-denis
# Processing Record 49 of Set 13 | caravelas
# Processing Record 50 of Set 13 | oistins
# Processing Record 1 of Set 14 | chatra
# Processing Record 2 of Set 14 | umm kaddadah
# Processing Record 3 of Set 14 | raudeberg
# Processing Record 4 of Set 14 | talara
# Processing Record 5 of Set 14 | tosham
# Processing Record 6 of Set 14 | jiayuguan
# Processing Record 7 of Set 14 | luwuk
# Processing Record 8 of Set 14 | barguzin
# Processing Record 9 of Set 14 | riyadh
# Processing Record 10 of Set 14 | launceston
# Processing Record 11 of Set 14 | gamba
# Processing Record 12 of Set 14 | sur
# Processing Record 13 of Set 14 | yantal
# Processing Record 14 of Set 14 | praia da vitoria
# Processing Record 15 of Set 14 | kamariotissa
# Processing Record 16 of Set 14 | kupang
# Processing Record 17 of Set 14 | afua
# Processing Record 18 of Set 14 | acarau
# Processing Record 19 of Set 14 | bonavista
# Processing Record 20 of Set 14 | kununurra
# Processing Record 21 of Set 14 | mongo
# Processing Record 22 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 23 of Set 14 | peniche
# Processing Record 24 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 14 | nabire
# Processing Record 26 of Set 14 | pemangkat
# Processing Record 27 of Set 14 | mangrol
# Processing Record 28 of Set 14 | turukhansk
# Processing Record 29 of Set 14 | prince rupert
# Processing Record 30 of Set 14 | ahipara
# Processing Record 31 of Set 14 | goderich
# Processing Record 32 of Set 14 | manzanillo
# Processing Record 33 of Set 14 | ust-nera
# Processing Record 34 of Set 14 | renqiu
# Processing Record 35 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 14 | sault sainte marie
# Processing Record 37 of Set 14 | pelym
# Processing Record 38 of Set 14 | bud
# Processing Record 39 of Set 14 | tautira
# Processing Record 40 of Set 14 | mattru
# Processing Record 41 of Set 14 | dalinghe
# City not found. Skipping...
# Processing Record 42 of Set 14 | mananjary
# Processing Record 43 of Set 14 | empalme
# Processing Record 44 of Set 14 | katobu
# Processing Record 45 of Set 14 | comrat
# Processing Record 46 of Set 14 | ulladulla
# Processing Record 47 of Set 14 | bela
# Processing Record 48 of Set 14 | atar
# Processing Record 49 of Set 14 | gao
# Processing Record 50 of Set 14 | villa maria
# Processing Record 1 of Set 15 | curumani
# Processing Record 2 of Set 15 | oranjestad
# Processing Record 3 of Set 15 | misratah
# Processing Record 4 of Set 15 | hambantota
# Processing Record 5 of Set 15 | meadow lake
# Processing Record 6 of Set 15 | posse
# Processing Record 7 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 15 | yerbogachen
# Processing Record 9 of Set 15 | awjilah
# Processing Record 10 of Set 15 | orlik
# Processing Record 11 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 15 | rio gallegos
# Processing Record 13 of Set 15 | makung
# City not found. Skipping...
# Processing Record 14 of Set 15 | newport
# Processing Record 15 of Set 15 | eenhana
# Processing Record 16 of Set 15 | yuci
# Processing Record 17 of Set 15 | tefe
# Processing Record 18 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 15 | kontagora
# Processing Record 20 of Set 15 | abashiri
# Processing Record 21 of Set 15 | carutapera
# Processing Record 22 of Set 15 | paucartambo
# City not found. Skipping...
# Processing Record 23 of Set 15 | gazanjyk
# Processing Record 24 of Set 15 | tual
# Processing Record 25 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 26 of Set 15 | belaya rechka
# Processing Record 27 of Set 15 | chokwe
# Processing Record 28 of Set 15 | taksimo
# Processing Record 29 of Set 15 | kolokani
# Processing Record 30 of Set 15 | vila do maio
# Processing Record 31 of Set 15 | kathu
# Processing Record 32 of Set 15 | edson
# Processing Record 33 of Set 15 | parana
# Processing Record 34 of Set 15 | evinayong
# Processing Record 35 of Set 15 | olafsvik
# Processing Record 36 of Set 15 | ziniare
# Processing Record 37 of Set 15 | muzhi
# Processing Record 38 of Set 15 | botwood
# Processing Record 39 of Set 15 | camacari
# Processing Record 40 of Set 15 | rocha
# Processing Record 41 of Set 15 | la rochelle
# Processing Record 42 of Set 15 | chicama
# Processing Record 43 of Set 15 | joshimath
# Processing Record 44 of Set 15 | zonguldak
# Processing Record 45 of Set 15 | petropavl
# Processing Record 46 of Set 15 | sangar
# Processing Record 47 of Set 15 | samarai
# Processing Record 48 of Set 15 | minakuchi
# Processing Record 49 of Set 15 | santa cruz de tenerife
# Processing Record 50 of Set 15 | acajutla
# Processing Record 1 of Set 16 | mount hagen
# Processing Record 2 of Set 16 | marquette
# Processing Record 3 of Set 16 | ayan
# Processing Record 4 of Set 16 | ukiah
# Processing Record 5 of Set 16 | svobodnyy
# Processing Record 6 of Set 16 | touros
# Processing Record 7 of Set 16 | yatou
# Processing Record 8 of Set 16 | bilibino
# Processing Record 9 of Set 16 | krasnystaw
# Processing Record 10 of Set 16 | melfi
# Processing Record 11 of Set 16 | huancavelica
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Phuthaditjhaba -28.52   28.82     53.64        78           0        2.55
# 1          Atuona  -9.80 -139.03     77.41        76          59       19.55
# 2    Ponta Do Sol  32.67  -17.10     69.80        73          40       14.99
# 3           Airai  -8.93  125.41     63.99        61          70        1.99
# 4         Ushuaia -54.80  -68.30     59.00        51          20        6.93
#
#   Country                 Date Current Description
# 0      ZA  2020-11-02 22:21:44           clear sky
# 1      PF  2020-11-02 22:21:44          light rain
# 2      PT  2020-11-02 22:21:44    scattered clouds
# 3      TL  2020-11-02 22:21:44       broken clouds
# 4      AR  2020-11-02 22:17:08          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Phuthaditjhaba      ZA -28.52   28.82     53.64        78           0
# 1          Atuona      PF  -9.80 -139.03     77.41        76          59
# 2    Ponta Do Sol      PT  32.67  -17.10     69.80        73          40
# 3           Airai      TL  -8.93  125.41     63.99        61          70
# 4         Ushuaia      AR -54.80  -68.30     59.00        51          20
# 5          Namibe      AO -15.20   12.15     68.81        76          29
# 6       Cape Town      ZA -33.93   18.42     66.99        82           0
# 7           Karoi      ZW -16.81   29.69     70.43        58          16
# 8          Hobart      AU -42.88  147.33     69.01        55          75
# 9         College      US  64.86 -147.80     -5.80        69          75
#
#    Wind Speed Current Description
# 0        2.55           clear sky
# 1       19.55          light rain
# 2       14.99    scattered clouds
# 3        1.99       broken clouds
# 4        6.93          few clouds
# 5        2.86    scattered clouds
# 6        8.05           clear sky
# 7       10.11          few clouds
# 8        9.17       broken clouds
# 9        4.70          light snow

# %%
# Create the output file (CSV).
output_data_file = "C:/Users/aboon/Desktop/Bootcamp Work/Module 6_APIs/World_Weather_AnalysisWeather_Database/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-e5f90ad33131> in <module>
#       2 output_data_file = "Weather_Database/WeatherPy_challenge.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_challenge.csv'

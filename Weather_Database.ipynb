# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=03357120a9caa81064d2a01508c51960

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
#city_url = url + "&q=" + "Boston"
#city_weather = requests.get(city_url)
#city_weather.json()

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | banjarmasin
# Processing Record 2 of Set 1 | lima
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | sabha
# Processing Record 8 of Set 1 | salalah
# Processing Record 9 of Set 1 | bambous virieux
# Processing Record 10 of Set 1 | santa rosalia
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | moranbah
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | mount isa
# Processing Record 18 of Set 1 | tuatapere
# Processing Record 19 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | playa del carmen
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | macapa
# Processing Record 24 of Set 1 | tezu
# Processing Record 25 of Set 1 | baracoa
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | lasa
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | solnechnyy
# Processing Record 32 of Set 1 | bonavista
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | guerrero negro
# Processing Record 35 of Set 1 | yumen
# Processing Record 36 of Set 1 | kahului
# Processing Record 37 of Set 1 | formoso do araguaia
# City not found. Skipping...
# Processing Record 38 of Set 1 | aklavik
# Processing Record 39 of Set 1 | sao filipe
# Processing Record 40 of Set 1 | oktyabrskiy
# Processing Record 41 of Set 1 | kirakira
# Processing Record 42 of Set 1 | klaksvik
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | college
# Processing Record 45 of Set 1 | bom despacho
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | margate
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | makat
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | hualmay
# Processing Record 3 of Set 2 | halkirk
# Processing Record 4 of Set 2 | verkhnyaya inta
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | eureka
# Processing Record 7 of Set 2 | kroonstad
# Processing Record 8 of Set 2 | lata
# Processing Record 9 of Set 2 | noumea
# Processing Record 10 of Set 2 | walvis bay
# Processing Record 11 of Set 2 | lorengau
# Processing Record 12 of Set 2 | calvinia
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | castro
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | saldanha
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | verkhnyaya toyma
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | svetlogorsk
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | neyshabur
# Processing Record 25 of Set 2 | yulara
# Processing Record 26 of Set 2 | albany
# Processing Record 27 of Set 2 | duvan
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | morgan city
# Processing Record 31 of Set 2 | galle
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 2 | padang
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | comodoro rivadavia
# Processing Record 37 of Set 2 | nizwa
# Processing Record 38 of Set 2 | pinheiro machado
# Processing Record 39 of Set 2 | nanortalik
# Processing Record 40 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 2 | namuac
# Processing Record 42 of Set 2 | lompoc
# Processing Record 43 of Set 2 | faanui
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | altay
# Processing Record 46 of Set 2 | half moon bay
# Processing Record 47 of Set 2 | nikolskoye
# Processing Record 48 of Set 2 | vestmannaeyjar
# Processing Record 49 of Set 2 | coahuayana
# Processing Record 50 of Set 2 | verkhoyansk
# Processing Record 1 of Set 3 | apatou
# Processing Record 2 of Set 3 | coquimbo
# Processing Record 3 of Set 3 | torbay
# Processing Record 4 of Set 3 | chardara
# Processing Record 5 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 6 of Set 3 | bengkulu
# Processing Record 7 of Set 3 | dunedin
# Processing Record 8 of Set 3 | pacific grove
# Processing Record 9 of Set 3 | asau
# Processing Record 10 of Set 3 | russell
# Processing Record 11 of Set 3 | grindavik
# Processing Record 12 of Set 3 | hamilton
# Processing Record 13 of Set 3 | makakilo city
# Processing Record 14 of Set 3 | dafeng
# Processing Record 15 of Set 3 | nago
# Processing Record 16 of Set 3 | hervey bay
# Processing Record 17 of Set 3 | neiafu
# Processing Record 18 of Set 3 | saint-georges
# Processing Record 19 of Set 3 | pevek
# Processing Record 20 of Set 3 | karasjok
# Processing Record 21 of Set 3 | quatre cocos
# Processing Record 22 of Set 3 | kuryk
# Processing Record 23 of Set 3 | taoudenni
# Processing Record 24 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 3 | raga
# Processing Record 26 of Set 3 | saskylakh
# Processing Record 27 of Set 3 | sorland
# Processing Record 28 of Set 3 | kununurra
# Processing Record 29 of Set 3 | newport
# Processing Record 30 of Set 3 | lahij
# Processing Record 31 of Set 3 | hithadhoo
# Processing Record 32 of Set 3 | alanya
# Processing Record 33 of Set 3 | jamestown
# Processing Record 34 of Set 3 | nouadhibou
# Processing Record 35 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 3 | umm lajj
# Processing Record 38 of Set 3 | new norfolk
# Processing Record 39 of Set 3 | qasigiannguit
# Processing Record 40 of Set 3 | neuquen
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | northam
# Processing Record 43 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 3 | kaitangata
# Processing Record 45 of Set 3 | ponta delgada
# Processing Record 46 of Set 3 | christchurch
# Processing Record 47 of Set 3 | mantua
# Processing Record 48 of Set 3 | zemio
# Processing Record 49 of Set 3 | atar
# Processing Record 50 of Set 3 | naze
# Processing Record 1 of Set 4 | lamu
# Processing Record 2 of Set 4 | tiksi
# Processing Record 3 of Set 4 | redlands
# Processing Record 4 of Set 4 | kavaratti
# Processing Record 5 of Set 4 | buala
# Processing Record 6 of Set 4 | a
# City not found. Skipping...
# Processing Record 7 of Set 4 | flinders
# Processing Record 8 of Set 4 | chumikan
# Processing Record 9 of Set 4 | coihaique
# Processing Record 10 of Set 4 | carnarvon
# Processing Record 11 of Set 4 | andenes
# Processing Record 12 of Set 4 | burnie
# Processing Record 13 of Set 4 | salekhard
# Processing Record 14 of Set 4 | suamico
# Processing Record 15 of Set 4 | talnakh
# Processing Record 16 of Set 4 | miyako
# Processing Record 17 of Set 4 | vagur
# Processing Record 18 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 4 | pergamino
# Processing Record 20 of Set 4 | cherskiy
# Processing Record 21 of Set 4 | saint george
# Processing Record 22 of Set 4 | bilibino
# Processing Record 23 of Set 4 | morondava
# Processing Record 24 of Set 4 | calama
# Processing Record 25 of Set 4 | adre
# Processing Record 26 of Set 4 | santa catarina de tepehuanes
# Processing Record 27 of Set 4 | codrington
# Processing Record 28 of Set 4 | alice springs
# Processing Record 29 of Set 4 | ravar
# Processing Record 30 of Set 4 | milyutinskaya
# Processing Record 31 of Set 4 | port lincoln
# Processing Record 32 of Set 4 | qaqortoq
# Processing Record 33 of Set 4 | vostok
# Processing Record 34 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 4 | durango
# Processing Record 36 of Set 4 | moroni
# Processing Record 37 of Set 4 | salto
# Processing Record 38 of Set 4 | krasnoselkup
# Processing Record 39 of Set 4 | paamiut
# Processing Record 40 of Set 4 | tapaua
# City not found. Skipping...
# Processing Record 41 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 4 | ayan
# Processing Record 43 of Set 4 | naron
# Processing Record 44 of Set 4 | gundorovskiy
# Processing Record 45 of Set 4 | kalevala
# Processing Record 46 of Set 4 | sokolo
# Processing Record 47 of Set 4 | richards bay
# Processing Record 48 of Set 4 | igrim
# Processing Record 49 of Set 4 | cabo san lucas
# Processing Record 50 of Set 4 | pangnirtung
# Processing Record 1 of Set 5 | byron bay
# Processing Record 2 of Set 5 | asfi
# Processing Record 3 of Set 5 | luderitz
# Processing Record 4 of Set 5 | meulaboh
# Processing Record 5 of Set 5 | karratha
# Processing Record 6 of Set 5 | turukhansk
# Processing Record 7 of Set 5 | belmonte
# Processing Record 8 of Set 5 | emba
# Processing Record 9 of Set 5 | uyuni
# Processing Record 10 of Set 5 | khombole
# Processing Record 11 of Set 5 | nara
# Processing Record 12 of Set 5 | natal
# Processing Record 13 of Set 5 | port macquarie
# Processing Record 14 of Set 5 | finschhafen
# Processing Record 15 of Set 5 | san patricio
# Processing Record 16 of Set 5 | zeya
# Processing Record 17 of Set 5 | buta
# Processing Record 18 of Set 5 | alyangula
# Processing Record 19 of Set 5 | sioux lookout
# Processing Record 20 of Set 5 | betong
# Processing Record 21 of Set 5 | khatanga
# Processing Record 22 of Set 5 | tonj
# Processing Record 23 of Set 5 | kuching
# Processing Record 24 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 5 | mount gambier
# Processing Record 26 of Set 5 | pisco
# Processing Record 27 of Set 5 | port hedland
# Processing Record 28 of Set 5 | oistins
# Processing Record 29 of Set 5 | gaoyou
# Processing Record 30 of Set 5 | honiara
# Processing Record 31 of Set 5 | victoria
# Processing Record 32 of Set 5 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 33 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 5 | zhigalovo
# Processing Record 35 of Set 5 | copiapo
# Processing Record 36 of Set 5 | guaratinga
# Processing Record 37 of Set 5 | bilma
# Processing Record 38 of Set 5 | faya
# Processing Record 39 of Set 5 | deputatskiy
# Processing Record 40 of Set 5 | penhold
# Processing Record 41 of Set 5 | alvand
# Processing Record 42 of Set 5 | mineral wells
# Processing Record 43 of Set 5 | maues
# Processing Record 44 of Set 5 | sitka
# Processing Record 45 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 5 | ancud
# Processing Record 47 of Set 5 | abapo
# Processing Record 48 of Set 5 | omsukchan
# Processing Record 49 of Set 5 | tondi
# Processing Record 50 of Set 5 | los llanos de aridane
# Processing Record 1 of Set 6 | clyde river
# Processing Record 2 of Set 6 | malinyi
# Processing Record 3 of Set 6 | cuiaba
# Processing Record 4 of Set 6 | araceli
# Processing Record 5 of Set 6 | colares
# Processing Record 6 of Set 6 | santa cruz
# Processing Record 7 of Set 6 | najran
# Processing Record 8 of Set 6 | kungurtug
# Processing Record 9 of Set 6 | fortuna
# Processing Record 10 of Set 6 | mao
# Processing Record 11 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 6 | bartica
# Processing Record 14 of Set 6 | panaba
# Processing Record 15 of Set 6 | mahon
# Processing Record 16 of Set 6 | avera
# Processing Record 17 of Set 6 | camana
# Processing Record 18 of Set 6 | anadyr
# Processing Record 19 of Set 6 | omboue
# Processing Record 20 of Set 6 | namibe
# Processing Record 21 of Set 6 | longyearbyen
# Processing Record 22 of Set 6 | maku
# Processing Record 23 of Set 6 | henties bay
# Processing Record 24 of Set 6 | terekli-mekteb
# Processing Record 25 of Set 6 | portland
# Processing Record 26 of Set 6 | abu samrah
# Processing Record 27 of Set 6 | jasper
# Processing Record 28 of Set 6 | talara
# Processing Record 29 of Set 6 | manzil jamil
# City not found. Skipping...
# Processing Record 30 of Set 6 | gimli
# Processing Record 31 of Set 6 | manyana
# Processing Record 32 of Set 6 | mackay
# Processing Record 33 of Set 6 | mecca
# Processing Record 34 of Set 6 | phuket
# Processing Record 35 of Set 6 | komsomolskiy
# Processing Record 36 of Set 6 | san jose
# Processing Record 37 of Set 6 | saint-denis
# Processing Record 38 of Set 6 | pinos
# Processing Record 39 of Set 6 | hobyo
# Processing Record 40 of Set 6 | lagoa
# Processing Record 41 of Set 6 | myanaung
# Processing Record 42 of Set 6 | vardo
# Processing Record 43 of Set 6 | barrow
# Processing Record 44 of Set 6 | zaoyang
# Processing Record 45 of Set 6 | altus
# Processing Record 46 of Set 6 | gardan diwal
# City not found. Skipping...
# Processing Record 47 of Set 6 | at-bashi
# Processing Record 48 of Set 6 | escuinapa
# Processing Record 49 of Set 6 | didwana
# Processing Record 50 of Set 6 | chara
# Processing Record 1 of Set 7 | harnosand
# Processing Record 2 of Set 7 | goma
# Processing Record 3 of Set 7 | caravelas
# Processing Record 4 of Set 7 | bandarbeyla
# Processing Record 5 of Set 7 | husavik
# Processing Record 6 of Set 7 | aksarka
# Processing Record 7 of Set 7 | san andres del rabanedo
# Processing Record 8 of Set 7 | beloha
# Processing Record 9 of Set 7 | san policarpo
# Processing Record 10 of Set 7 | trofors
# Processing Record 11 of Set 7 | morros
# Processing Record 12 of Set 7 | saint-philippe
# Processing Record 13 of Set 7 | abu road
# Processing Record 14 of Set 7 | lewisporte
# Processing Record 15 of Set 7 | anori
# Processing Record 16 of Set 7 | turkistan
# Processing Record 17 of Set 7 | weifang
# Processing Record 18 of Set 7 | dawson creek
# Processing Record 19 of Set 7 | kosh-agach
# Processing Record 20 of Set 7 | vestmanna
# Processing Record 21 of Set 7 | hami
# Processing Record 22 of Set 7 | puerto el triunfo
# Processing Record 23 of Set 7 | pitimbu
# Processing Record 24 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 7 | chuy
# Processing Record 26 of Set 7 | axim
# Processing Record 27 of Set 7 | lashio
# Processing Record 28 of Set 7 | kattivakkam
# Processing Record 29 of Set 7 | puke
# Processing Record 30 of Set 7 | buchanan
# Processing Record 31 of Set 7 | ponta do sol
# Processing Record 32 of Set 7 | port elizabeth
# Processing Record 33 of Set 7 | nuuk
# Processing Record 34 of Set 7 | touros
# Processing Record 35 of Set 7 | cabo rojo
# Processing Record 36 of Set 7 | acapulco
# Processing Record 37 of Set 7 | salym
# Processing Record 38 of Set 7 | lavrentiya
# Processing Record 39 of Set 7 | morshansk
# Processing Record 40 of Set 7 | lebu
# Processing Record 41 of Set 7 | mizque
# Processing Record 42 of Set 7 | bracebridge
# Processing Record 43 of Set 7 | charleston
# Processing Record 44 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 7 | vila franca do campo
# Processing Record 46 of Set 7 | leningradskiy
# Processing Record 47 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 49 of Set 7 | itarema
# Processing Record 50 of Set 7 | jibuti
# Processing Record 1 of Set 8 | monkey bay
# Processing Record 2 of Set 8 | khani
# Processing Record 3 of Set 8 | walldurn
# Processing Record 4 of Set 8 | hay river
# Processing Record 5 of Set 8 | motril
# Processing Record 6 of Set 8 | corsicana
# Processing Record 7 of Set 8 | aguas formosas
# Processing Record 8 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 8 | chicama
# Processing Record 10 of Set 8 | hopkinsville
# Processing Record 11 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 8 | port moresby
# Processing Record 13 of Set 8 | shenjiamen
# Processing Record 14 of Set 8 | poum
# Processing Record 15 of Set 8 | cayenne
# Processing Record 16 of Set 8 | ilulissat
# Processing Record 17 of Set 8 | willowmore
# Processing Record 18 of Set 8 | the valley
# Processing Record 19 of Set 8 | saint-pierre
# Processing Record 20 of Set 8 | broken hill
# Processing Record 21 of Set 8 | ginda
# Processing Record 22 of Set 8 | iskateley
# Processing Record 23 of Set 8 | zhemtala
# Processing Record 24 of Set 8 | east london
# Processing Record 25 of Set 8 | kulhudhuffushi
# Processing Record 26 of Set 8 | neryungri
# Processing Record 27 of Set 8 | evanston
# Processing Record 28 of Set 8 | hohhot
# Processing Record 29 of Set 8 | coari
# Processing Record 30 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 8 | kindia
# Processing Record 33 of Set 8 | erzin
# Processing Record 34 of Set 8 | marsh harbour
# Processing Record 35 of Set 8 | savinka
# Processing Record 36 of Set 8 | hailun
# Processing Record 37 of Set 8 | orange cove
# Processing Record 38 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 8 | beibei
# Processing Record 40 of Set 8 | inyonga
# Processing Record 41 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 8 | port-de-paix
# City not found. Skipping...
# Processing Record 43 of Set 8 | turayf
# Processing Record 44 of Set 8 | palauig
# Processing Record 45 of Set 8 | kokorevka
# Processing Record 46 of Set 8 | kilindoni
# Processing Record 47 of Set 8 | malazgirt
# Processing Record 48 of Set 8 | qandahar
# City not found. Skipping...
# Processing Record 49 of Set 8 | yokadouma
# Processing Record 50 of Set 8 | basirpur
# Processing Record 1 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 9 | balasinor
# City not found. Skipping...
# Processing Record 3 of Set 9 | norman wells
# Processing Record 4 of Set 9 | nossa senhora do socorro
# Processing Record 5 of Set 9 | santa rosa
# Processing Record 6 of Set 9 | oussouye
# Processing Record 7 of Set 9 | gambela
# Processing Record 8 of Set 9 | pietarsaari
# Processing Record 9 of Set 9 | hasaki
# Processing Record 10 of Set 9 | solaro
# Processing Record 11 of Set 9 | olinda
# Processing Record 12 of Set 9 | mallama
# City not found. Skipping...
# Processing Record 13 of Set 9 | borujan
# City not found. Skipping...
# Processing Record 14 of Set 9 | juegang
# Processing Record 15 of Set 9 | kandalaksha
# Processing Record 16 of Set 9 | mount vernon
# Processing Record 17 of Set 9 | olafsvik
# Processing Record 18 of Set 9 | namatanai
# Processing Record 19 of Set 9 | geraldton
# Processing Record 20 of Set 9 | ferrol
# Processing Record 21 of Set 9 | provideniya
# Processing Record 22 of Set 9 | seydisehir
# Processing Record 23 of Set 9 | posse
# Processing Record 24 of Set 9 | taga dzong
# City not found. Skipping...
# Processing Record 25 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 9 | vao
# Processing Record 27 of Set 9 | alofi
# Processing Record 28 of Set 9 | panama city
# Processing Record 29 of Set 9 | batagay-alyta
# Processing Record 30 of Set 9 | kavieng
# Processing Record 31 of Set 9 | mehamn
# Processing Record 32 of Set 9 | killarney
# Processing Record 33 of Set 9 | zhanaozen
# Processing Record 34 of Set 9 | auki
# Processing Record 35 of Set 9 | beckley
# Processing Record 36 of Set 9 | cockburn town
# Processing Record 37 of Set 9 | chokurdakh
# Processing Record 38 of Set 9 | zyryanka
# Processing Record 39 of Set 9 | awjilah
# Processing Record 40 of Set 9 | severo-kurilsk
# Processing Record 41 of Set 9 | rundu
# Processing Record 42 of Set 9 | charagua
# Processing Record 43 of Set 9 | high level
# Processing Record 44 of Set 9 | mazamari
# Processing Record 45 of Set 9 | liuhe
# Processing Record 46 of Set 9 | katsuura
# Processing Record 47 of Set 9 | jutai
# Processing Record 48 of Set 9 | kastamonu
# Processing Record 49 of Set 9 | beringovskiy
# Processing Record 50 of Set 9 | berlevag
# Processing Record 1 of Set 10 | kyshtovka
# Processing Record 2 of Set 10 | deshnok
# Processing Record 3 of Set 10 | gamba
# Processing Record 4 of Set 10 | tasiilaq
# Processing Record 5 of Set 10 | yenagoa
# Processing Record 6 of Set 10 | dali
# Processing Record 7 of Set 10 | upernavik
# Processing Record 8 of Set 10 | harper
# Processing Record 9 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 10 of Set 10 | vila velha
# Processing Record 11 of Set 10 | hofn
# Processing Record 12 of Set 10 | port-gentil
# Processing Record 13 of Set 10 | chirilagua
# Processing Record 14 of Set 10 | polaniec
# Processing Record 15 of Set 10 | takoradi
# Processing Record 16 of Set 10 | somerset east
# Processing Record 17 of Set 10 | belaya gora
# Processing Record 18 of Set 10 | maniitsoq
# Processing Record 19 of Set 10 | north bend
# Processing Record 20 of Set 10 | kyabe
# Processing Record 21 of Set 10 | viedma
# Processing Record 22 of Set 10 | yeppoon
# Processing Record 23 of Set 10 | dudinka
# Processing Record 24 of Set 10 | souillac
# Processing Record 25 of Set 10 | port perry
# Processing Record 26 of Set 10 | chipinge
# Processing Record 27 of Set 10 | olecko
# Processing Record 28 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 10 | dongsheng
# Processing Record 30 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 31 of Set 10 | sao miguel do araguaia
# Processing Record 32 of Set 10 | fort nelson
# Processing Record 33 of Set 10 | chapada dos guimaraes
# Processing Record 34 of Set 10 | bhawana
# Processing Record 35 of Set 10 | tagusao
# Processing Record 36 of Set 10 | merauke
# Processing Record 37 of Set 10 | darab
# Processing Record 38 of Set 10 | isangel
# Processing Record 39 of Set 10 | zheleznodorozhnyy
# Processing Record 40 of Set 10 | san juan
# Processing Record 41 of Set 10 | yelizovo
# Processing Record 42 of Set 10 | gwadar
# Processing Record 43 of Set 10 | saint-augustin
# Processing Record 44 of Set 10 | corner brook
# Processing Record 45 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 10 | chokwe
# Processing Record 47 of Set 10 | tazovskiy
# Processing Record 48 of Set 10 | tongliao
# Processing Record 49 of Set 10 | bereznik
# Processing Record 50 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 11 | gombong
# Processing Record 2 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 11 | ongandjera
# Processing Record 4 of Set 11 | maracaibo
# Processing Record 5 of Set 11 | cartagena
# Processing Record 6 of Set 11 | asosa
# Processing Record 7 of Set 11 | piranshahr
# Processing Record 8 of Set 11 | santa teresa
# Processing Record 9 of Set 11 | sidrolandia
# Processing Record 10 of Set 11 | ketchikan
# Processing Record 11 of Set 11 | gunnaur
# Processing Record 12 of Set 11 | ust-kut
# Processing Record 13 of Set 11 | spring valley
# Processing Record 14 of Set 11 | te anau
# Processing Record 15 of Set 11 | sosnogorsk
# Processing Record 16 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 17 of Set 11 | vinh
# Processing Record 18 of Set 11 | dingle
# Processing Record 19 of Set 11 | edson
# Processing Record 20 of Set 11 | san cristobal
# Processing Record 21 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 11 | bumba
# Processing Record 23 of Set 11 | gorin
# Processing Record 24 of Set 11 | iqaluit
# Processing Record 25 of Set 11 | zheleznogorsk-ilimskiy
# Processing Record 26 of Set 11 | seitin
# Processing Record 27 of Set 11 | constitucion
# Processing Record 28 of Set 11 | xining
# Processing Record 29 of Set 11 | izhma
# Processing Record 30 of Set 11 | sao gabriel da cachoeira
# Processing Record 31 of Set 11 | egvekinot
# Processing Record 32 of Set 11 | exmouth
# Processing Record 33 of Set 11 | muscat
# Processing Record 34 of Set 11 | tamiahua
# Processing Record 35 of Set 11 | grand gaube
# Processing Record 36 of Set 11 | mookane
# Processing Record 37 of Set 11 | riyadh
# Processing Record 38 of Set 11 | baykit
# Processing Record 39 of Set 11 | camacha
# Processing Record 40 of Set 11 | roebourne
# Processing Record 41 of Set 11 | kidal
# Processing Record 42 of Set 11 | bayangol
# Processing Record 43 of Set 11 | nhulunbuy
# Processing Record 44 of Set 11 | cochrane
# Processing Record 45 of Set 11 | camiri
# Processing Record 46 of Set 11 | iquitos
# Processing Record 47 of Set 11 | galich
# Processing Record 48 of Set 11 | rawson
# Processing Record 49 of Set 11 | mazyr
# Processing Record 50 of Set 11 | channel-port aux basques
# Processing Record 1 of Set 12 | elk point
# Processing Record 2 of Set 12 | shelburne
# Processing Record 3 of Set 12 | bathsheba
# Processing Record 4 of Set 12 | cascas
# Processing Record 5 of Set 12 | athabasca
# Processing Record 6 of Set 12 | lac du bonnet
# Processing Record 7 of Set 12 | skegness
# Processing Record 8 of Set 12 | laguna
# Processing Record 9 of Set 12 | kardailovo
# Processing Record 10 of Set 12 | muriti
# Processing Record 11 of Set 12 | cap malheureux
# Processing Record 12 of Set 12 | hvolsvollur
# Processing Record 13 of Set 12 | seoul
# Processing Record 14 of Set 12 | koppies
# Processing Record 15 of Set 12 | srednekolymsk
# Processing Record 16 of Set 12 | ayorou
# Processing Record 17 of Set 12 | haridwar
# Processing Record 18 of Set 12 | karakulino
# Processing Record 19 of Set 12 | guilin
# Processing Record 20 of Set 12 | huntsville
# Processing Record 21 of Set 12 | copacabana
# Processing Record 22 of Set 12 | cururupu
# Processing Record 23 of Set 12 | haines junction
# Processing Record 24 of Set 12 | alexandria
# Processing Record 25 of Set 12 | middleton
# Processing Record 26 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 12 | bulalacao
# Processing Record 28 of Set 12 | noshiro
# Processing Record 29 of Set 12 | ariano irpino
# Processing Record 30 of Set 12 | aykhal
# Processing Record 31 of Set 12 | westport
# Processing Record 32 of Set 12 | katha
# City not found. Skipping...
# Processing Record 33 of Set 12 | visnes
# Processing Record 34 of Set 12 | ahipara
# Processing Record 35 of Set 12 | kalemie
# Processing Record 36 of Set 12 | nioro
# Processing Record 37 of Set 12 | pantelho
# Processing Record 38 of Set 12 | paramonga
# Processing Record 39 of Set 12 | marzuq
# Processing Record 40 of Set 12 | kloulklubed
# Processing Record 41 of Set 12 | kruisfontein
# Processing Record 42 of Set 12 | sooke
# Processing Record 43 of Set 12 | kakamega
# Processing Record 44 of Set 12 | port-cartier
# Processing Record 45 of Set 12 | elizabeth city
# Processing Record 46 of Set 12 | batesville
# Processing Record 47 of Set 12 | lavras da mangabeira
# Processing Record 48 of Set 12 | klyuchi
# Processing Record 49 of Set 12 | taltal
# Processing Record 50 of Set 12 | busok
# Processing Record 1 of Set 13 | ode
# Processing Record 2 of Set 13 | vanavara
# Processing Record 3 of Set 13 | kalmunai
# Processing Record 4 of Set 13 | jurilovca
# Processing Record 5 of Set 13 | pareora
# Processing Record 6 of Set 13 | kirkland lake
# Processing Record 7 of Set 13 | van buren
# Processing Record 8 of Set 13 | diego de almagro
# Processing Record 9 of Set 13 | buraydah
# Processing Record 10 of Set 13 | nasice
# Processing Record 11 of Set 13 | namwala
# Processing Record 12 of Set 13 | awbari
# Processing Record 13 of Set 13 | mount darwin
# Processing Record 14 of Set 13 | rovaniemi
# Processing Record 15 of Set 13 | caarapo
# Processing Record 16 of Set 13 | mporokoso
# Processing Record 17 of Set 13 | rio grande
# Processing Record 18 of Set 13 | inhambane
# Processing Record 19 of Set 13 | urmary
# Processing Record 20 of Set 13 | praia da vitoria
# Processing Record 21 of Set 13 | raymond
# Processing Record 22 of Set 13 | ginir
# Processing Record 23 of Set 13 | mersin
# Processing Record 24 of Set 13 | nisia floresta
# Processing Record 25 of Set 13 | sibolga
# Processing Record 26 of Set 13 | sovetskiy
# Processing Record 27 of Set 13 | palmer
# Processing Record 28 of Set 13 | tommot
# Processing Record 29 of Set 13 | lazaro cardenas
# Processing Record 30 of Set 13 | bijar
# Processing Record 31 of Set 13 | pacifica
# Processing Record 32 of Set 13 | aleksandrovskoye
# Processing Record 33 of Set 13 | moba
# Processing Record 34 of Set 13 | kushima
# Processing Record 35 of Set 13 | jalu
# Processing Record 36 of Set 13 | ruidoso
# Processing Record 37 of Set 13 | broome
# Processing Record 38 of Set 13 | promyshlennaya
# Processing Record 39 of Set 13 | haapu
# City not found. Skipping...
# Processing Record 40 of Set 13 | huarmey
# Processing Record 41 of Set 13 | brae
# Processing Record 42 of Set 13 | imbituba
# Processing Record 43 of Set 13 | blacksburg
# Processing Record 44 of Set 13 | yar-sale
# Processing Record 45 of Set 13 | mundo nuevo
# Processing Record 46 of Set 13 | nantucket
# Processing Record 47 of Set 13 | samarai
# Processing Record 48 of Set 13 | tessalit
# Processing Record 49 of Set 13 | kangaatsiaq
# Processing Record 50 of Set 13 | tambul
# City not found. Skipping...
# Processing Record 1 of Set 14 | camapua
# Processing Record 2 of Set 14 | ouargaye
# Processing Record 3 of Set 14 | ilembula
# Processing Record 4 of Set 14 | cooma
# Processing Record 5 of Set 14 | lakes entrance
# Processing Record 6 of Set 14 | shingu
# Processing Record 7 of Set 14 | tecoanapa
# Processing Record 8 of Set 14 | kikwit
# Processing Record 9 of Set 14 | sechura
# Processing Record 10 of Set 14 | stokmarknes
# Processing Record 11 of Set 14 | armstrong
# Processing Record 12 of Set 14 | tarrafal
# Processing Record 13 of Set 14 | krasnoye
# Processing Record 14 of Set 14 | kedrovyy
# Processing Record 15 of Set 14 | raudeberg
# Processing Record 16 of Set 14 | voyvozh
# Processing Record 17 of Set 14 | hovd
# Processing Record 18 of Set 14 | isla mujeres
# Processing Record 19 of Set 14 | korla
# Processing Record 20 of Set 14 | dandong
# Processing Record 21 of Set 14 | bam
# Processing Record 22 of Set 14 | adrar
# Processing Record 23 of Set 14 | ballina
# Processing Record 24 of Set 14 | novoagansk
# Processing Record 25 of Set 14 | tabarqah
# City not found. Skipping...
# Processing Record 26 of Set 14 | vastervik
# City not found. Skipping...
# Processing Record 27 of Set 14 | mitsamiouli
# Processing Record 28 of Set 14 | nishihara
# Processing Record 29 of Set 14 | luganville
# Processing Record 30 of Set 14 | candawaga
# City not found. Skipping...
# Processing Record 31 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 32 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 33 of Set 14 | bonfim
# Processing Record 34 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 35 of Set 14 | yanam
# Processing Record 36 of Set 14 | marsaxlokk
# Processing Record 37 of Set 14 | tokur
# Processing Record 38 of Set 14 | vyartsilya
# Processing Record 39 of Set 14 | tura
# Processing Record 40 of Set 14 | el ejido
# Processing Record 41 of Set 14 | sao felix do xingu
# Processing Record 42 of Set 14 | bougouni
# Processing Record 43 of Set 14 | gat
# Processing Record 44 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 45 of Set 14 | lardos
# Processing Record 46 of Set 14 | aden
# Processing Record 47 of Set 14 | kingston
# Processing Record 48 of Set 14 | ibra
# Processing Record 49 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 50 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 15 | sao joao da barra
# Processing Record 2 of Set 15 | svetlaya
# Processing Record 3 of Set 15 | coruripe
# Processing Record 4 of Set 15 | gornopravdinsk
# Processing Record 5 of Set 15 | ranau
# Processing Record 6 of Set 15 | celestun
# Processing Record 7 of Set 15 | marsa matruh
# Processing Record 8 of Set 15 | sibu
# Processing Record 9 of Set 15 | elbrus
# Processing Record 10 of Set 15 | mamou
# Processing Record 11 of Set 15 | puerto del rosario
# Processing Record 12 of Set 15 | benito juarez
# Processing Record 13 of Set 15 | leninskoye
# Processing Record 14 of Set 15 | otaru
# Processing Record 15 of Set 15 | aksu
# Processing Record 16 of Set 15 | chiknayakanhalli
# Processing Record 17 of Set 15 | reefton
# City not found. Skipping...
# Processing Record 18 of Set 15 | batagay
# Processing Record 19 of Set 15 | lishui
# Processing Record 20 of Set 15 | bulnes
# Processing Record 21 of Set 15 | santo antonio do sudoeste
# Processing Record 22 of Set 15 | aguadilla
# Processing Record 23 of Set 15 | sangar
# Processing Record 24 of Set 15 | lokoja
# Processing Record 25 of Set 15 | argelia
# Processing Record 26 of Set 15 | tiarei
# Processing Record 27 of Set 15 | san rafael
# Processing Record 28 of Set 15 | waverley
# Processing Record 29 of Set 15 | okha
# Processing Record 30 of Set 15 | west plains
# Processing Record 31 of Set 15 | wangaratta
# Processing Record 32 of Set 15 | huangchuan
# Processing Record 33 of Set 15 | arlit
# Processing Record 34 of Set 15 | la gaulette
# City not found. Skipping...
# Processing Record 35 of Set 15 | eydhafushi
# Processing Record 36 of Set 15 | lukovetskiy
# Processing Record 37 of Set 15 | itoman
# Processing Record 38 of Set 15 | ksenyevka
# City not found. Skipping...
# Processing Record 39 of Set 15 | urumqi
# Processing Record 40 of Set 15 | suntar
# Processing Record 41 of Set 15 | puro
# Processing Record 42 of Set 15 | tilichiki
# Processing Record 43 of Set 15 | rockland
# Processing Record 44 of Set 15 | tres arroyos
# Processing Record 45 of Set 15 | bud
# Processing Record 46 of Set 15 | manta
# Processing Record 47 of Set 15 | ca mau
# Processing Record 48 of Set 15 | odweyne
# Processing Record 49 of Set 15 | terra santa
# Processing Record 50 of Set 15 | shush
# Processing Record 1 of Set 16 | bairiki
# Processing Record 2 of Set 16 | vaitape
# Processing Record 3 of Set 16 | saleilua
# City not found. Skipping...
# Processing Record 4 of Set 16 | fairlie
# Processing Record 5 of Set 16 | le vauclin
# Processing Record 6 of Set 16 | voyinka
# Processing Record 7 of Set 16 | amboasary
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Banjarmasin  -3.32  114.59     73.87        96         100        2.64
# 1         Lima -12.04  -77.03     68.00        72          20        8.05
# 2      Ushuaia -54.80  -68.30     59.00        51          20        6.93
# 3       Hobart -42.88  147.33     66.00        55          75        9.17
# 4        Vaini -21.20 -175.20     78.80        83          40       12.75
#
#   Country                 Date Current Description
# 0      ID  2020-11-02 22:09:41          light rain
# 1      PE  2020-11-02 22:07:57          few clouds
# 2      AR  2020-11-02 21:57:29          few clouds
# 3      AU  2020-11-02 21:57:41       broken clouds
# 4      TO  2020-11-02 22:02:00    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Banjarmasin      ID  -3.32  114.59     73.87        96         100
# 1             Lima      PE -12.04  -77.03     68.00        72          20
# 2          Ushuaia      AR -54.80  -68.30     59.00        51          20
# 3           Hobart      AU -42.88  147.33     66.00        55          75
# 4            Vaini      TO -21.20 -175.20     78.80        83          40
# 5            Sabha      LY  27.04   14.43     63.73        50           0
# 6          Salalah      OM  17.02   54.09     75.20        57           0
# 7  Bambous Virieux      MU -20.34   57.76     69.80        77          75
# 8    Santa Rosalia      MX  27.32 -112.28     84.42        31           0
# 9       Bredasdorp      ZA -34.53   20.04     66.20        82          35
#
#    Wind Speed Current Description
# 0        2.64          light rain
# 1        8.05          few clouds
# 2        6.93          few clouds
# 3        9.17       broken clouds
# 4       12.75    scattered clouds
# 5        9.17           clear sky
# 6        3.36           clear sky
# 7       11.41         shower rain
# 8        6.08           clear sky
# 9       12.75    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-a661121541ea> in <module>
#       2 output_data_file = "Weather_Database/WeatherPy.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy.csv'
